# %% [markdown]
# # Scientific Software Template Walkthrough
#
# A step-by-step notebook for learning this repository, running the starter commands, and deciding which tools you want to adopt for your project.
#
# ## Navigation
#
# - 1. Rename Starter Package (one-time)
# - 2. Get Up and Running
# - 3. Verify the Template
# - 4. Explore the Starter Package
# - 5. Edit These Files First
# - 6. Tool Checklist
# - 7. Build and Publish Docs
# - 8. Suggested Workflow
# - 9. Tutorials and References

# %% [markdown]
# ## Before You Start
#
# This notebook is meant to be used from the repository root. Most command cells call `make`, and the `makefile` already routes tools through the conda environment stored in `./envs`.
#
# ### What you should do while working through it
#
# - Run the setup cells once before trying the later checks.
# - Read the Markdown cells before executing the command cells.
# - Use this notebook as a checklist the first week, then return only to the sections you need.
#
# ### Helpful references
#
# - Repository overview: [README.md](README.md)
# - Jupyter basics: https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Notebook%20Basics.html
# - Software Carpentry lessons: https://swcarpentry.github.io/
# - Conda environments: https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html

# %%
# Check repository for basic starter files (just a check)
from pathlib import Path

repo_root = Path.cwd()
print(f"Notebook working directory: {repo_root}")

key_files = [
    "README.md",
    "environment.yml",
    "makefile",
    "pyproject.toml",
    "scripts/rename_package.py",
    "mypackage/example.py",
    "mypackage/tests/test_pytest.py",
]

print("\nKey starter files:")
for relative_path in key_files:
    status = "present" if (repo_root / relative_path).exists() else "missing"
    print(f"- {relative_path}: {status}")
# Out:
# Notebook working directory: /Users/sophiesunderland/Desktop/CMSE802F26
#
# Key starter files:
# - README.md: missing
# - environment.yml: present
# - makefile: present
# - pyproject.toml: present
# - scripts/rename_package.py: present
# - mypackage/example.py: missing
# - mypackage/tests/test_pytest.py: missing

# %% [markdown]
# ## 1. Rename Starter Package (One-Time)
#
# If you plan to use a package name other than `mypackage`, run the helper cell below once before `make init`. This updates the package folder and common references for you.
#
# Use lowercase letters, numbers, and underscores only (for example `soil_analysis`).
#
# If you want to keep the default name `mypackage`, skip the rename cell and continue to setup.

# %%
# Set your package name and run once. Then set back to "mypackage" to avoid reruns.

# new_package_name = "territorial_inequality"  # example: "soil_analysis"
new_package_name = "mypackage"

if new_package_name == "mypackage":
    print("Skipping rename. Keeping default package name: mypackage")
else:
    # !python scripts/rename_package.py {new_package_name}
    print("Rename complete. Re-run the file check cell above if you want to verify updates.")
# Out:
# Renamed package folder: mypackage -> territorial_inequality
# Updated references in 13 files.
# Done. Next step: run `make test` to verify the rename.
# Rename complete. Re-run the file check cell above if you want to verify updates.

# %%
# !make init
# !conda run --prefix ./envs python --version
# !conda run --prefix ./envs pytest --version
# Out:
# conda env create --prefix=./.envs -f environment.yml || \
# 	conda env update --prefix=./.envs -f environment.yml --prune
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# ...
# Solving environment: done
#
# ...
# scipy-1.17.0         | 14.4 MB   |                                       |   0%
# pandas-3.0.0         | 13.5 MB   |                                       |   0%
#
# python-3.12.12       | 13.1 MB   |                                       |   0%
#
#
# mypy-1.19.1          | 13.1 MB   |                                       |   0%
#
#
#
# scikit-learn-1.8.0   | 8.9 MB    |                                       |   0%
#
#
#
#
# matplotlib-base-3.10 | 7.9 MB    |                                       |   0%
#
#
#
#
#
# numpy-2.4.2          | 7.6 MB    |                                       |   0%
#
#
#
#
#
#
# virtualenv-21.7.9    | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
# ...

# %% [markdown]
# ## 2. Verify the Template
#
# Once the environment exists, run the starter tests. This is the quickest way to confirm the repository is usable before you begin editing code.
#
# If this cell fails, stop and fix the environment or dependency problem before moving further.

# %%
# !make test

# %% [markdown]
# ## 3. Explore the Starter Package
#
# Before replacing the example code with your own work, import the sample functions once so you can see what a working package looks like in this template.
#
# This section is also a reminder that notebooks should import from your package instead of duplicating important logic inside the notebook itself.

# %%
from territorial_inequality.example import clip_and_scale, power_self

print(f"power_self(3) -> {power_self(3)}")
print(f"clip_and_scale(12.0, min_value=10.0, max_value=20.0) -> {clip_and_scale(12.0, min_value=10.0, max_value=20.0)}")
# Out:
# power_self(3) -> 27
# clip_and_scale(12.0, min_value=10.0, max_value=20.0) -> 0.2

# %% [markdown]
# ## 5. Edit These Files First
#
# After the template works, the best next step is to replace the starter examples with your own project structure.
#
# ### Recommended first edits
#
# - If needed, run `python scripts/rename_package.py your_package_name` once (or use the rename cell above).
# - Replace `mypackage/example.py` with your own module or modules.
# - Rewrite `mypackage/tests/test_pytest.py` so the tests describe your own code.
# - Update `README.md` with your project purpose, install notes, and usage examples.
# - Add a short notebook or script that demonstrates the main analysis workflow for your project.
#
# ### Student checklist
#
# - [ ] I can create the environment with `make init`.
# - [ ] I can run `make test` before editing code.
# - [ ] I confirmed my package name and import path.
# - [ ] I identified the first function or class I want to implement.
# - [ ] I know which optional tools I want to use this week.

# %% [markdown]
# ## 5. Tool Checklist
#
# Use this section as a menu, not a requirement list. Start with `make test`, then add other tools only when they help your project.
#
# | Tool | Command in this repo | Why you might use it | Tutorial |
# | --- | --- | --- | --- |
# | Conda | `make init` | Create a reproducible environment. | https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-environments.html |
# | Pytest | `make test` | Check code behavior automatically. | https://docs.pytest.org/en/stable/getting-started.html |
# | Black | `make format` | Auto-format Python code. | https://black.readthedocs.io/en/stable/getting_started.html |
# | Ruff | `make lint` | Catch common bugs and style issues. | https://docs.astral.sh/ruff/tutorial/ |
# | MyPy | `make type` | Check type hints for mismatches. | https://mypy.readthedocs.io/en/stable/getting_started.html |
# | Pydocstyle | `make doclint` | Check docstring style. | https://www.pydocstyle.org/en/stable/ |
# | pip-audit | `make audit` | Look for known dependency vulnerabilities. | https://pypi.org/project/pip-audit/ |
# | detect-secrets | `make secrets` | Scan for accidentally committed secrets. | https://github.com/Yelp/detect-secrets |
# | nbstripout | `make nb-clean` | Clean notebook output before committing. | https://github.com/kynan/nbstripout |
# | pdoc | `make docs` | Build simple API documentation from docstrings. | https://pdoc.dev/docs/pdoc.html |
# | pre-commit | `conda run --prefix ./envs pre-commit run --all-files` | Run selected checks before commit. | https://pre-commit.com/ |

# %%
# Remove the leading # from one command at a time when you are ready to try it.
# !make format
# !make lint
# !make type
# !make doclint
# !make audit
# !make secrets
# !make docs
# !conda run --prefix ./envs pre-commit run --all-files

# %% [markdown]
# ## 6. Build and Publish Docs
#
# If you write docstrings in your package, this template can build HTML API docs into the `docs/` directory. The notebook cell below runs that build locally.
#
# For publishing, this repository already includes a GitHub Pages walkthrough and an automated workflow:
#
# - GitHub Pages tutorial: [GITHUB_PAGES_TUTORIAL.md](GITHUB_PAGES_TUTORIAL.md)
# - Pages workflow: [.github/workflows/pages.yml](.github/workflows/pages.yml)
# - pdoc tutorial: https://pdoc.dev/docs/pdoc.html
# - GitHub Pages docs: https://docs.github.com/pages/getting-started-with-github-pages/creating-a-github-pages-site

# %%
# !make docs

# %% [markdown]
# ## 7. Suggested Workflow
#
# A simple pattern for the first few weeks of a project is:
#
# 1. Run `make init` once after pulling new environment changes.
# 2. Write or edit code in your package, not only in notebooks.
# 3. Run `make test` after each small change.
# 4. Add `make format` or `make lint` if style and bug-catching feedback would help.
# 5. Build docs with `make docs` when your docstrings become useful to readers.
#
# If your team is using GitHub pull requests, `make check-full` is a good pre-share command once you are comfortable with the optional tools.

# %% [markdown]
# ## 8. Tutorials and References
#
# Use these when you want more background or a worked example beyond this notebook.
#
# - Pytest getting started: https://docs.pytest.org/en/stable/getting-started.html
# - Pytest good practices: https://docs.pytest.org/en/stable/explanation/goodpractices.html
# - Black getting started: https://black.readthedocs.io/en/stable/getting_started.html
# - Ruff tutorial: https://docs.astral.sh/ruff/tutorial/
# - MyPy getting started: https://mypy.readthedocs.io/en/stable/getting_started.html
# - pdoc docs: https://pdoc.dev/docs/pdoc.html
# - JupyterLab overview: https://jupyterlab.readthedocs.io/en/stable/getting_started/overview.html
# - GitHub Pages tutorial in this repo: [GITHUB_PAGES_TUTORIAL.md](GITHUB_PAGES_TUTORIAL.md)
# - Rules for research repositories: https://colbrydi.github.io/Research_guidelines/Rules_for_Repos.html
